# %% [markdown]
# <a href="https://colab.research.google.com/github/cse2024220084-spec/used-car-price-prediction/blob/main/notebooks/03_model_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model: Linear Regression
# **Owner:** Ly Kimchanphanuth

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import sys
sys.path.append('../src')

from evaluate import evaluate_model, save_metrics
from utils import save_model
from prepocessing import scale_features
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load Processed Data

# %%
train_df = pd.read_csv('../data/processed/train.csv')
test_df = pd.read_csv('../data/processed/test.csv')

# %% [markdown]
# ## TODO: One-hot encode categoricals, scale numeric features (see preprocessing.scale_features)

# %%
X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = scale_features(train_df, test_df)

print("X_train shape:", X_train,shape)
print("X_test shape:", X_test.shape)
print("y_train shape", y_train.shape)
print("y_test shape", y_test.shape)

model= LinearRegression()
model.fit(X_train, y_train)

y_pred = model.preduct(X_test)

# %% [markdown]
# ## Evaluate

# %%
metrics = evaluate_model
 (y_test,
  y_pred,
  "Linear Regreesion"
  )

save_metrics(metrics)
metrics

# %% [markdown]
# ## Save Model (joblib)Saves to `../models/linear_regression.joblib` so the FastAPI app can load it without retraining.

# %%
# save_model(model, 'linear_regression')

# %% [markdown]
# ## Coefficient Interpretation- TODO: which features have the largest positive/negative coefficients?

# %%
coefficients =pd.Series(
    model.coef_,
    index=X_train.columns
)
print("Largest positive coefficients:")
print(coefficients.sort_values(ascending=Falsde).head())

print("\nLargest negative coefficients:")
print(coefficients.sort_values().head())
